# %% [markdown]
# # <u>JED Testing
# # This notebook contains tests for the JED Software</u>
# #### Last Revision: May, 2018
# #### Author: Charles David

# %% [markdown]
# ### Define Project:
# * Define Variables and Bash Functions

# %%
USER="cflcyd"
NAME="JED"
PROJECT="/workspace/${USER}/git/${NAME}"
NOTES="${PROJECT}/NOTES"
TEMP="/workspace/${USER}/tmp"

TMPFS="/dev/shm/${USER}/${NAME}"
JTMP="/dev/shm/${USER}/JAVATMP"

JED="/workspace/cflcyd/git/JED/jars/JED_Driver.jar"
FES="/workspace/cflcyd/git/JED/jars/FES_Driver.jar"
FSSA="/workspace/cflcyd/git/JED/jars/FSSA_Driver.jar"
FSSA_Iterated="/workspace/cflcyd/git/JED/jars/FSSA_Iterated_Driver.jar"
POOL="/workspace/cflcyd/git/JED/jars/POOL_Driver.jar"
SSA="/workspace/cflcyd/git/JED/jars/SSA_Driver.jar"
VIZ="/workspace/cflcyd/git/JED/jars/VIZ_Driver.jar"

# %% [markdown]
# #### setJava () is used to define the java command that sets up the java VM:
# * The function has Two required args and One optional arg:
#     * ` Xms   Xmx   [-jar] `
#     * Create enough heap space
#     * Idealy, set `Xms=Xmx`
#     * Specify `-jar` if running a jar file
#         * Example usage: `setJava 16G 16G -jar`
#         * NOTE: Currently, the JVM cannot access shared memory and large pages
#         * Currently using Java version 1.8

# %%
setJava () {
JAVA="java \
      -d64 \
      -server \
      -Xms${1} \
      -Xmx${2} \
      -Xconcurrentio \
      -XX:+AggressiveOpts \
      -XX:+AlwaysPreTouch \
      -XX:+UseG1GC \
      -XX:MaxGCPauseMillis=500 \
      -XX:ParallelGCThreads=8 \
      -XX:ConcGCThreads=2 \
      -XX:+UseStringDeduplication \
      -XX:-UseGCOverheadLimit \
      -XX:InitiatingHeapOccupancyPercent=75 \
      -Djava.io.tmpdir=${TEMP} ${3}"
}

# %% [markdown]
# ### SINGLE CHAIN PDBs PRE-PROCESSING JOB
# * JED Driver Input File:

# %% [raw]
# 1      0
# /workspace/cflcyd/git/JED/test/Single/PDBs/
# TEST_PRE-PROCESSING_SINGLE 			1A6N.pdb

# %%
module load java
setJava 8G 8G -jar

INPUT="/workspace/cflcyd/git/JED/input_files/JED_Driver_Single_PP.txt"
OUT="/workspace/cflcyd/git/JED/test/Single/PDBs"

COMMAND="${JAVA} ${JED} ${INPUT}"

bsub -o ${OUT}/TEST_PRE-PROCESSING_SINGLE.out \
     -e ${OUT}/TEST_PRE-PROCESSING_SINGLE.err \
     -J JED_SPP \
     ${COMMAND}

# %% [raw]
# Running JED Driver:
# Getting the input file:
# The path to the input file must be the first argument:
# These are the command args:
# Arg 1 Value = /workspace/cflcyd/git/JED/input_files/JED_Driver_Single_PP.txt
# Working Directory = /tmp/hsperfdata_cflcyd
# Input File Path = /workspace/cflcyd/git/JED/input_files/JED_Driver_Single_PP.txt
# Reading Input File...
# Reading the input file: /workspace/cflcyd/git/JED/input_files/JED_Driver_Single_PP.txt
# Below are the parameters to be processed:
# ----------------------------------------------------------------------------------------------------------------------
# 1      0	//SINGLE CHAIN PDBs PRE-PROCESSING JOB
# /workspace/cflcyd/git/JED/test/Single/PDBs/
# TEST_PRE-PROCESSING_SINGLE 			1A6N.pdb
# ----------------------------------------------------------------------------------------------------------------------
# The number of lines of parameters in the input file is: 3
#
# Processing line: 1
# 	READ PDBs = true
# 	MULTI CHAIN PDBs = false
# Processing line: 2
# 	Working Directory = /workspace/cflcyd/git/JED/test/Single/PDBs/
# Processing line: 3
# 	Description = TEST_PRE-PROCESSING_SINGLE
# 	PDB Reference File = 1A6N.pdb
# Done.
# Reading PDB Reference File...
# Done.
# Reading PDB files... Done. (131.689 seconds)
# Performing Pre-Processing of PDB files for JED Analysis... Done. (14.318 seconds)
# JED successfully completed: 2018-05-16 16:38:44

# %% [markdown]
# ### MULTI CHAIN PDBs PRE-PROCESSING JOB
# * JED Driver Input File:

# %% [raw]
# 1      1
# /workspace/cflcyd/git/JED/test/Multi/PDBs/
# TEST_PRE-PROCESSING_MULTI 			MVb_A_B_ATP.pdb

# %%
module load java
setJava 8G 8G -jar

INPUT="/workspace/cflcyd/git/JED/input_files/JED_Driver_Multi_PP.txt"
OUT="/workspace/cflcyd/git/JED/test/Multi/PDBs"

COMMAND="${JAVA} ${JED} ${INPUT}"

${COMMAND}

# %% [raw]
# Running JED Driver:
# Getting the input file:
# The path to the input file must be the first argument:
# These are the command args:
# Arg 1 Value = /workspace/cflcyd/git/JED/input_files/JED_Driver_Multi_PP.txt
# Working Directory = /tmp/hsperfdata_cflcyd
# Input File Path = /workspace/cflcyd/git/JED/input_files/JED_Driver_Multi_PP.txt
# Reading Input File...
# Reading the input file: /workspace/cflcyd/git/JED/input_files/JED_Driver_Multi_PP.txt
# Below are the parameters to be processed:
# ----------------------------------------------------------------------------------------------------------------------
# 1    1
# /workspace/cflcyd/git/JED/test/Multi/PDBs/
# TEST_PRE-PROCESSING_MULTI		MVb_A_B_ATP.pdb
# ----------------------------------------------------------------------------------------------------------------------
# The number of lines of parameters in the input file is: 3
#
# Processing line: 1
# 	READ PDBs = true
# 	MULTI CHAIN PDBs = true
# Processing line: 2
# 	Working Directory = /workspace/cflcyd/git/JED/test/Multi/PDBs/
# Processing line: 3
# 	Description = TEST_PRE-PROCESSING_MULTI
# 	PDB Reference File = MVb_A_B_ATP.pdb
# Done.
# Reading PDB Reference File...
# Done.
# Reading PDB files... Done. (26.995 seconds)
# Performing Pre-Processing of PDB files for JED Analysis... Done. (5.372 seconds)
# JED successfully completed: 2018-05-16 16:44:57

# %% [markdown]
# ### SINGLE CHAIN JOB
# * JED Driver Input File:
#     * cPCA
#     * dpPCA
#     * VIZ
#     * z-cutoff set to 3.0

# %% [raw]
# 0      0
# /workspace/cflcyd/git/JED/test/Single/
# TEST_SINGLE			1A6N.pdb
# 0.00    3.00
# 20     10     5     3.0
# residues.txt
# residue_pairs.txt
# original_PDB_Coordinates.txt

# %%
module load java
setJava 8G 8G -jar

INPUT="/workspace/cflcyd/git/JED/input_files/JED_Driver_Single.txt"
OUT="/workspace/cflcyd/git/JED/test/Single"

COMMAND="${JAVA} ${JED} ${INPUT}"

${COMMAND}

# %% [raw]
# Running JED Driver:
# Getting the input file:
# The path to the input file must be the first argument:
# These are the command args:
# Arg 1 Value = /workspace/cflcyd/git/JED/input_files/JED_Driver_Single.txt
# Working Directory = /tmp/hsperfdata_cflcyd
# Input File Path = /workspace/cflcyd/git/JED/input_files/JED_Driver_Single.txt
# Reading Input File...
# Reading the input file: /workspace/cflcyd/git/JED/input_files/JED_Driver_Single.txt
# Below are the parameters to be processed:
# ----------------------------------------------------------------------------------------------------------------------
# 0      0
# /workspace/cflcyd/git/JED/test/Single/
# TEST_SINGLE			1A6N.pdb
# 0.00    3.00
# 20     10     5     3.0
# residues.txt
# residue_pairs.txt
# original_PDB_Coordinates.txt
# ----------------------------------------------------------------------------------------------------------------------
# The number of lines of parameters in the input file is: 8
#
# Processing line: 1
# 	READ PDBs = false
# 	MULTI CHAIN PDBs = false
# Processing line: 2
# 	Working Directory = /workspace/cflcyd/git/JED/test/Single/
# Processing line: 3
# 	Description = TEST_SINGLE
# 	PDB Reference File = 1A6N.pdb
# Processing line: 4
# 	Percent = 0.0
# 	Z-Cutoff = 3.0
# Processing line: 5
# 	#Cartesian Modes = 20
# 	#Distance Pair Modes = 10
# 	#Modes Viz = 5
# 	Mode Amplitude = 3.0
# Processing line: 6
# 	Cartesian Residue List = residues.txt
# Processing line: 7
# 	Residue Pairs List = residue_pairs.txt
# Processing line: 8
# 	Matrix of Coordinates = original_PDB_Coordinates.txt
# Done.
# Reading PDB Reference File...
# Done.
# Reading Coordinate File... Done. (0.751 seconds)
# Performing cPCA analysis... Done. (64.946 seconds)
# Performing dpPCA analysis... Done. (2.681 seconds)
# Performing mode visualization... Done. (54.568 seconds)
# JED successfully completed: 2018-05-16 17:10:50

# %% [markdown]
# ### MULTI CHAIN JOB
# * JED Driver Input File:
#     * cPCA
#     * dpPCA
#     * VIZ
#     * z-cutoff set to 3.0

# %% [raw]
# 0      1
# /workspace/cflcyd/git/JED/test/Multi/
# TEST_MULTI			MVb_A_B_ATP.pdb
# 0.00     3.00
# 20     5     5     3.0
# residues.txt
# residue_pairs.txt
# original_PDB_Coordinates.txt

# %%
module load java
setJava 8G 8G -jar

INPUT="/workspace/cflcyd/git/JED/input_files/JED_Driver_Multi.txt"
OUT="/workspace/cflcyd/git/JED/test/Multi"

COMMAND="${JAVA} ${JED} ${INPUT}"

${COMMAND}

# %% [raw]
# Running JED Driver:
# Getting the input file:
# The path to the input file must be the first argument:
# These are the command args:
# Arg 1 Value = /workspace/cflcyd/git/JED/input_files/JED_Driver_Multi.txt
# Working Directory = /tmp/hsperfdata_cflcyd
# Input File Path = /workspace/cflcyd/git/JED/input_files/JED_Driver_Multi.txt
# Reading Input File...
# Reading the input file: /workspace/cflcyd/git/JED/input_files/JED_Driver_Multi.txt
# Below are the parameters to be processed:
# ----------------------------------------------------------------------------------------------------------------------
# 0      1
# /workspace/cflcyd/git/JED/test/Multi/
# TEST_MULTI			MVb_A_B_ATP.pdb
# 0.00     0.00
# 20     5     5     3.0
# residues.txt
# residue_pairs.txt
# original_PDB_Coordinates.txt
# ----------------------------------------------------------------------------------------------------------------------
# The number of lines of parameters in the input file is: 8
#
# Processing line: 1
# 	READ PDBs = false
# 	MULTI CHAIN PDBs = true
# Processing line: 2
# 	Working Directory = /workspace/cflcyd/git/JED/test/Multi/
# Processing line: 3
# 	Description = TEST_MULTI
# 	PDB Reference File = MVb_A_B_ATP.pdb
# Processing line: 4
# 	Percent = 0.0
# 	Z-Cutoff = 0.0
# Processing line: 5
# 	#Cartesian Modes = 20
# 	#Distance Pair Modes = 5
# 	#Modes Viz = 5
# 	Mode Amplitude = 3.0
# Processing line: 6
# 	Cartesian Residue List = residues.txt
# Processing line: 7
# 	Residue Pairs List = residue_pairs.txt
# Processing line: 8
# 	Matrix of Coordinates = original_PDB_Coordinates.txt
# Done.
# Reading PDB Reference File...
# Done.
# Reading Coordinate File... Done. (0.314 seconds)
# Performing cPCA analysis... Done. (12.194 seconds)
# Performing dpPCA analysis... Done. (1.530 seconds)
# Performing mode visualization... Done. (43.063 seconds)
# JED successfully completed: 2018-05-16 17:13:42

# %% [markdown]
# ### FES
# * FES Driver Input File:

# %%
3
/workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/FES/
Test_FES
******************************************************************************************************
Test_1
/workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
ss_151_top_20_weighted_DVPs_CORR.txt
1     2     2000     0     0
******************************************************************************************************
Test_2
/workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
ss_151_top_20_weighted_DVPs_CORR.txt
1     3     2000     0     0
******************************************************************************************************
Test_3
/workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
ss_151_top_20_weighted_DVPs_CORR.txt
2     3     2000     0     0
******************************************************************************************************

# %%
module load java
setJava 8G 8G -jar

INPUT="/workspace/cflcyd/git/JED/input_files/FES.txt"
OUT="/workspace/cflcyd/git/JED/test"

COMMAND="${JAVA} ${FES} ${INPUT}"

${COMMAND}

# %% [raw]
# Running FES Driver:
# Getting the input file:
# The path to the input file must be the first argument:
# These are the command args:
# Arg 1 Value = /workspace/cflcyd/git/JED/input_files/FES.txt
# Working Directory = /tmp/hsperfdata_cflcyd
# Input File Path = /workspace/cflcyd/git/JED/input_files/FES.txt
# Reading Input File...
# Below is the input file that was read: /workspace/cflcyd/git/JED/input_files/FES.txt
# ----------------------------------------------------------------------------------------------------------------------
# 3
# /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/FES/
# Test_FES
# ******************************************************************************************************
# Test_1
# /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
# ss_151_top_20_weighted_DVPs_CORR.txt
# 1     2     2000     0     0
# ******************************************************************************************************
# Test_2
# /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
# ss_151_top_20_weighted_DVPs_CORR.txt
# 1     3     2000     0     0
# ******************************************************************************************************
# Test_3
# /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
# ss_151_top_20_weighted_DVPs_CORR.txt
# 2     3     2000     0     0
# ******************************************************************************************************
# ----------------------------------------------------------------------------------------------------------------------
# The number of lines of parameters in the input file is: 19
#
# Reading line 1
# 	The number of jobs =  3
# Reading line 2
# 	Output Directory = /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/FES/
# 	The output directory does not exist.
# 	Attempting to create it:
# 		Success.
# Reading line 3
# 	Batch Description = Test_FES
# Reading line 4
# ******************************************************************************************************
#
# Reading line 5,  LINE 1 of job: 1
# 	Job Description = Test_1
# Reading line 6,  LINE 2 of job: 1
# 	Job Directory = /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
# Reading line 7,  LINE 3 of job: 1
# 	The Delta Vectors = ss_151_top_20_weighted_DVPs_CORR.txt
# Reading line 8,  LINE 4 of job: 1
# 	OP1 = 0
# 	OP2 = 1
# 	Number of points to use = 2000
# 	Offset = 0
# 	Cellsize = 0.0
# Program will automatically calculate a cellsize.
# Reading line 9
# ******************************************************************************************************
#
# The bounds for the KDE are: OP1(-2221.124,377.048); OP2(-185.114,699.442)
# The effective cellsize is: 10.149109374999998
# Kernel Bandwidths are: 7.823	3.313
# Reading line 10,  LINE 1 of job: 2
# 	Job Description = Test_2
# Reading line 11,  LINE 2 of job: 2
# 	Job Directory = /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
# Reading line 12,  LINE 3 of job: 2
# 	The Delta Vectors = ss_151_top_20_weighted_DVPs_CORR.txt
# Reading line 13,  LINE 4 of job: 2
# 	OP1 = 0
# 	OP2 = 2
# 	Number of points to use = 2000
# 	Offset = 0
# 	Cellsize = 0.0
# Program will automatically calculate a cellsize.
# Reading line 14
# ******************************************************************************************************
#
# The bounds for the KDE are: OP1(-2221.124,377.048); OP2(-541.931,331.489)
# The effective cellsize is: 10.149109374999998
# Kernel Bandwidths are: 6.584	1.983
# Reading line 15,  LINE 1 of job: 3
# 	Job Description = Test_3
# Reading line 16,  LINE 2 of job: 3
# 	Job Directory = /workspace/cflcyd/git/JED/test/Single/JED_RESULTS_TEST_SINGLE/cPCA/CORR/
# Reading line 17,  LINE 3 of job: 3
# 	The Delta Vectors = ss_151_top_20_weighted_DVPs_CORR.txt
# Reading line 18,  LINE 4 of job: 3
# 	OP1 = 1
# 	OP2 = 2
# 	Number of points to use = 2000
# 	Offset = 0
# 	Cellsize = 0.0
# Program will automatically calculate a cellsize.
# Reading line 19
# ******************************************************************************************************
#
# The bounds for the KDE are: OP1(-185.114,699.442); OP2(-541.931,331.489)
# The effective cellsize is: 3.455296875
# Kernel Bandwidths are: 2.957	2.169
